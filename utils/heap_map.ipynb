# %%
import seaborn as sns
import numpy as np
# %matplotlib inline
sns.set(font_scale=0.5)
sample1 = [0, 9.9812108e-01, 9.9007016e-01, 9.9988472e-01,
 9.9952006e-01, 9.9768412e-01, 9.9891853e-01, 9.9900395e-01, 9.9784148e-01,
 9.9957794e-01, 0,0,0,0,0,0] #[1.5397955e-04, 9.9812108e-01, 9.9007016e-01, 9.9988472e-01,9.9952006e-01, 9.9768412e-01, 9.9891853e-01, 9.9900395e-01, 9.9784148e-01,9.9957794e-01, 0,0,0,0,0,0] #10
sample2 = [9.9313122e-01, 9.9945086e-01, 9.9979240e-01, 9.9589062e-01,
 8.4161210e-01, 9.9899048e-01, 9.8740792e-01, 4.8059887e-01, 9.9098760e-01,
 9.9116021e-01, 9.7431445e-01, 9.9858594e-01, 9.9905533e-01, 0,
0, 9.9897647e-01] #16 [9.9313122e-01, 9.9945086e-01, 9.9979240e-01, 9.9589062e-01,8.4161210e-01, 9.9899048e-01, 9.8740792e-01, 4.8059887e-01, 9.9098760e-01,9.9116021e-01, 9.7431445e-01, 9.9858594e-01, 9.9905533e-01, 6.6576444e-04,1.4449362e-04, 9.9897647e-01]
sample3 = [ 0.9248135,  0.99757534, 0.9664741,  0.99565816, 0.9851305,
 0.99676055, 0.99535453, 0.99742365, 0.9922495,0,0,0,0,0,0,0 ] #9

# %%
sns.set(rc = {'figure.figsize':(12, 2)})
data = [sample1, sample2, sample3]
mask = np.zeros_like(data)
mask[0, 10:] = 1
mask[2, 9:] = 1
with sns.axes_style("white"):
    sns.heatmap(data=data,vmin=0,vmax=1,center=0.3,annot=True,fmt=".2g",cmap="RdBu_r",linewidth=1.0, mask=mask)
